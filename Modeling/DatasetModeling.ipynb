# %%
import pandas as pd

# %%
df_ddos = pd.read_csv('../Datasets/MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')

# %%
df_portScan = pd.read_csv('../Datasets/MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')

# %%
df_pcap = pd.read_csv('../Datasets/MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv')

# %%
df_web = pd.read_csv('../Datasets/MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')

# %%
df_attacks = pd.read_csv('../Datasets/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv')

# %% [markdown]
# ### 2. Every dataset label categories

# %% [markdown]
# #### 2.1 DDOS

# %%
df_ddos.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              54865               3                   2
# 1              55054             109                   1
# 2              55055              52                   1
# 3              46236              34                   1
# 4              54863               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        1                            6
# 2                        1                            6
# 3                        1                            6
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             6                       6
# 2                             6                       6
# ...

# %%
df_ddos[' Label'].value_counts()
# Out:
# DDoS      128027
# BENIGN     97718
# Name:  Label, dtype: int64

# %% [markdown]
# #### 2.2 PortScan

# %%
df_portScan.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 22         1266342                  41
# 1                 22         1319353                  41
# 2                 22             160                   1
# 3                 22         1303488                  41
# 4              35396              77                   1
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       44                         2664
# 1                       44                         2664
# 2                        1                            0
# 3                       42                         2728
# 4                        2                            0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                          6954                     456
# 1                          6954                     456
# 2                             0                       0
# ...

# %%
df_portScan[' Label'].value_counts()
# Out:
# PortScan    158930
# BENIGN      127537
# Name:  Label, dtype: int64

# %% [markdown]
# #### 2.3 PCAP

# %%
df_pcap.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0               3268       112740690                  32
# 1                389       112740560                  32
# 2                  0       113757377                 545
# 3               5355          100126                  22
# 4                  0           54760                   4
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       16                         6448
# 1                       16                         6448
# 2                        0                            0
# 3                        0                          616
# 4                        0                            0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                          1152                     403
# 1                          5056                     403
# 2                             0                       0
# ...

# %%
df_pcap[' Label'].value_counts()
# Out:
# BENIGN    189067
# Bot         1966
# Name:  Label, dtype: int64

# %% [markdown]
# #### 2.4 WEB

# %%
df_web.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                389       113095465                  48
# 1                389       113473706                  68
# 2                  0       119945515                 150
# 3                443        60261928                   9
# 4                 53             269                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       24                         9668
# 1                       40                        11364
# 2                        0                            0
# 3                        7                         2330
# 4                        2                          102
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                         10012                     403
# 1                         12718                     403
# 2                             0                       0
# ...

# %%
df_web[' Label'].value_counts()
# Out:
# BENIGN                        168186
# Web Attack � Brute Force        1507
# Web Attack � XSS                 652
# Web Attack � Sql Injection        21
# Name:  Label, dtype: int64

# %% [markdown]
# #### 2.5 ATTACKS

# %%
df_attacks.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 80           38308                   1
# 1                389             479                  11
# 2                 88            1095                  10
# 3                389           15206                  17
# 4                 88            1092                   9
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            6
# 1                        5                          172
# 2                        6                         3150
# 3                       12                         3452
# 4                        6                         3150
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             6                       6
# 1                           326                      79
# 2                          3150                    1575
# ...

# %%
df_attacks[' Label'].value_counts()
# Out:
# BENIGN              440031
# DoS Hulk            231073
# DoS GoldenEye        10293
# DoS slowloris         5796
# DoS Slowhttptest      5499
# Heartbleed              11
# Name:  Label, dtype: int64

# %% [markdown]
# ### 3. JOIN datasets

# %%
final_df = pd.concat([df_ddos, df_portScan, df_pcap, df_web, df_attacks])

# %%
final_df[' Label'].value_counts()
# Out:
# BENIGN                        1022539
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1966
# Web Attack � Brute Force         1507
# Web Attack � XSS                  652
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name:  Label, dtype: int64

# %%
final_df[' Label'] = final_df[' Label'].map({'BENIGN': 0, 'DoS Hulk': 1, 'PortScan': 2, 'DDoS': 3, 'DoS GoldenEye': 4, 'DoS slowloris': 5, 'DoS Slowhttptest' : 6, 'Bot': 7, 'Web Attack � Brute Force': 8, 'Web Attack � XSS': 8, 'Web Attack � Sql Injection': 8, 'Heartbleed': 9})

# %%
final_df = final_df.rename(columns = {' Label': 'Target' })

# %%
final_df['Target'].value_counts()
# Out:
# 0    1022539
# 1     231073
# 2     158930
# 3     128027
# 4      10293
# 5       5796
# 6       5499
# 8       2180
# 7       1966
# 9         11
# Name: Target, dtype: int64

# %%
final_df.corrwith(final_df['Target']).nlargest(11)
# Out:
# ...
#   Obtaining dependency information for pycaret from https://files.pythonhosted.org/packages/c7/d8/4e703f17f17d7d7764fe6d586872e787ce3a248640221f5f2d586f671eee/pycaret-3.3.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for scikit-learn>1.4.0 from https://files.pythonhosted.org/packages/7b/0e/25d6b5678ed3c7e12bc94d047d0e9492e89cc78b7ea0034ac0f1cf2ff304/scikit_learn-1.4.1.post1-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/160.5 kB ? eta -:--:--
#      ------------------------------------ - 153.6/160.5 kB 3.1 MB/s eta 0:00:01
#      -------------------------------------- 160.5/160.5 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
final_df.corrwith(final_df['Target']).nsmallest(11)
# Out:
#  Bwd Packet Length Min    -0.304814
#  Min Packet Length        -0.298503
#  URG Flag Count           -0.155563
#  Destination Port         -0.146165
#  Fwd Packet Length Mean   -0.112379
#  Avg Fwd Segment Size     -0.112379
#  Fwd Packet Length Min    -0.104921
#  Fwd Packet Length Max    -0.103408
#  Fwd Packet Length Std    -0.085749
# Bwd IAT Total             -0.078146
# dtype: float64

# %%
arr = [df_ddos, df_portScan, df_pcap, df_web, df_attacks]

# %%
##for i in arr:
  ##  labels = dict(i[' Label'].value_counts())
    
  ##  print(i.corrwith(i[' Label']).abs().nlargest(21))

# %% [markdown]
# ### 4. Pycaret

# %%
# install full version
# !pip install pycaret

# %%
from pycaret.classification import *

# %%
duplicate_indices = final_df[final_df.index.duplicated()]
print(duplicate_indices.sum())
# Out:
#  Destination Port              5.119137e+09
#  Flow Duration                 1.999524e+13
#  Total Fwd Packets             1.009604e+07
#  Total Backward Packets        1.159488e+07
# Total Length of Fwd Packets    4.420591e+08
#                                    ...
# Idle Mean                      1.474195e+13
#  Idle Std                      3.248839e+11
#  Idle Max                      1.502312e+13
#  Idle Min                      1.447687e+13
# Target                         5.593760e+05
# Length: 79, dtype: float64

# %%
final_df = final_df[~final_df.index.duplicated()]
final_df.reset_index(drop=True, inplace=True)

# %%
import numpy as np
# Reemplazar infinitos con NaN
final_df.replace([np.inf, -np.inf], np.nan, inplace=True)

# Eliminar filas con NaN
final_df.dropna(inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler
##scaler = MinMaxScaler()
## df_normalized = pd.DataFrame(scaler.fit_transform(final_df), columns=final_df.columns)

target = final_df['Target']
features = final_df.drop(columns=['Target'])

# Aplicar la normalización solo a las características
scaler = MinMaxScaler()
features_normalized = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)

# Concatenar las características normalizadas con la variable objetivo
final_df_normalized = pd.concat([features_normalized, target], axis=1)

# %%
final_df_normalized['Target'].value_counts()
# Out:
# 0.0    496373
# 3.0    128025
# 1.0     32427
# 2.0     25063
# 4.0     10293
# 9.0        11
# Name: Target, dtype: int64

# %%
final_df_normalized.dropna(subset=['Target'], inplace=True)

# %%
setup(final_df_normalized, target='Target')
# Out:
# <style type="text/css">
# #T_96af9_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_96af9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96af9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_96af9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96af9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96af9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_96af9_row0_col1" class="data row0 col1" >1846</td>
#     </tr>
#     <tr>
#       <th id="T_96af9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_96af9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_96af9_row1_col1" class="data row1 col1" >Target</td>
#     </tr>
#     <tr>
#       <th id="T_96af9_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models(errors = 'raise')
# Out:
# <style type="text/css">
# #T_97dae th {
#   text-align: left;
# }
# ...

# %%
best_model = compare_models(errors = 'raise')
# Out:
# <style type="text/css">
# </style>
# <table id="T_57a76">
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
# Ajuste del modelo seleccionado
final_model = create_model(best_model)

# Evaluación del modelo
evaluate_model(final_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Ajuste del modelo seleccionado
# ----> 2 final_model = create_model(best_model)
#       4 # Evaluación del modelo
#       5 evaluate_model(final_model)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pycaret\utils\generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pycaret\classification\functional.py:1001, in create_model(estimator, fold, round, cross_validation, fit_kwargs, groups, probability_threshold, experiment_custom_tags, engine, verbose, return_train_score, **kwargs)
#     872 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
# ...

# %%
predictions = predict_model(final_model, data=test_data)
